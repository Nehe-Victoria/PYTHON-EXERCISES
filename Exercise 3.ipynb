# %%
# Concatenate  the string 'Thirty', 'Days', 'Of', 'Python' to a single string
word_1 = "Thirty"
word_2 = "Days"
word_3 = "Of"
word_4 = "Python"
space = " "
result = word_1 + space + word_2 + space + word_3 + space + word_4
print(result)
# Out:
# Thirty Days Of Python

# %%
#  Concatenate the string 'Coding', 'For' , 'All' to a single string
word_1 = "Coding"
word_2 = "For"
word_3 = "All"
space = " "
sentence = word_1 + space + word_2 + space + word_3
print (sentence)
# Out:
# Coding For All

# %%
# Declare a variable named company and assign it to an initial value
Company = "Coding For All"
print(Company)
# Out:
# Coding For All

# %%
# Print the length of the company string using len() method and print()
len(Company)
print(len(Company))
# Out:
# 14

# %%
# Change all the characters to uppercase letters using upper() method
result = Company.upper()
print(result)
# Out:
# CODING FOR ALL

# %%
#  Change all the characters to lowercase letters using lower() method
result = Company.lower()
print(result)
# Out:
# coding for all

# %%
# Capitalize string method
capitalize_string = Company.capitalize()
print(capitalize_string)
# Out:
# Coding for all

# %%
# title string method
title_string = Company.title()
print(title_string)
# Out:
# Coding For All

# %%
# swapcase string method
swapcase_string = Company.swapcase()
print(swapcase_string)
# Out:
# cODING fOR aLL

# %%
# Cut(slice) out the first word of Coding For All string
text = "Coding For All"
result = (text[6:])
print(result)
# Out:
#  For All

# %%
# Check if Coding For All string contains a word Coding using the method index
try:
    result = text.index("Coding")
    print("The word 'Coding' is found at index{result}.")
except ValueError:
    print("The word 'Coding' is not found in the string.")
# Out:
# The word 'Coding' is found at index{result}.

# %%
new_text = text.replace("Coding", "Python")
print(new_text)
# Out:
# Python For All

# %%
# Change Python for Everyone to Python for All using the replace method 
text = "Python for Everyone"
new_text = text.replace("Everyone","All")
print(new_text)
# Out:
# Python for All

# %%
# Split the string 'Coding For All' using space as the separator (split())
text = 'Coding For All'
new_text = text.split()
print(new_text)
# Out:
# ['Coding', 'For', 'All']

# %%
# Splitting the strings "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" 
text = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" 
result = text.split(",")
print(result)
# Out:
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']

# %%
# Character at index 0 in the string Coding For All
string = "Coding For All"
Character_index_0 = string[0]
print(Character_index_0)
# Out:
# C

# %%
# last index of the string Coding For All
Last_index = len(string) - 1
print(Last_index)
# Out:
# 13

# %%
# Creating an acronym or an abbreviation for the name 'Python For Everyone'
acronym = "Py4A"
print("Abbreviation for the name Python For Everyone:",acronym)
# Out:
# Abbreviation for the name Python For Everyone: Py4A

# %%
#  Creating an acronym or an abbreviation for the name 'Coding For All'.
acronym = "C4A"
print("Abbreviation for the name 'Coding For All':",acronym)
# Out:
# Abbreviation for the name 'Coding For All': C4A

# %%
# Using index to determine the position of the first occurrence of C in Coding For All.
string = " Coding For All"
position = string.index("C")
print(position)
# Out:
# 1

# %%
# Using index to determine the position of the first occurrence of F in Coding For All.
position = string.index('F')
print(position)
# Out:
# 8

# %%
# Using rfind to determine the position of the last occurrence of l in Coding For All People
position = string.rfind("l")
print(position)
# Out:
# 14

# %%
# Using index to find the position of the first occurrence of the word 'because' in the following sentence: 
#'You cannot end a sentence with because because because is a conjunction'
sentence = "You cannot end a sentence with because because because is a conjunction"
position = sentence.index('because')
print(position)
# Out:
# 31

# %%
# Using find method
position = sentence.find('because')
print(position)
# Out:
# 31

# %%
# Using rindex to find the position of the last occurrence of the word because in the following sentence: 'You cannot end a sentence with
# because because because is a conjunction
position = sentence.rfind('because')
print(position)
# Out:
# 47

# %%
# Slice out the phrase 'because because because' in the following sentence: 'You cannot 
#end a sentence with because because because is a conjunction'
start_index = sentence.index("because")
end_index = start_index + len("because because because")
slice_phrase = sentence[start_index:end_index]
print(slice_phrase)
# Out:
# because because because

# %%
# Finding the position of the occurance of the word "because"
position = sentence.index("because")
print(position)
# Out:
# 31

# %%
# Slice out the phrase 'because because because' in the following sentence: 'You cannot 
# end a sentence with because because because is a conjunction'
new_sentence = sentence.replace(slice_phrase,"")
print(new_sentence)
# Out:
# You cannot end a sentence with  is a conjunction

# %%
# Does'Coding For All' start with a substring Coding
string = "Coding For All"
start_with_coding = string.startswith("Coding")
print("Does 'Coding For All' start with a 'Coding'?:",start_with_coding)
# Out:
# Does 'Coding For All' start with a 'Coding'?: True

# %%
# Does 'Coding For All' end with a substring coding?
end_with_coding = string.endswith("Coding")
print("Does 'Coding For All' end with  a substring 'Coding'?:", end_with_coding)
# Out:
# Does 'Coding For All' end with  a substring 'Coding'?: False

# %%
# ' Coding For All ' , remove the left and right trailing spaces in the given string.

# %%
string = ' Coding For All '
remove_left_space = string.strip()
print(remove_left_space)
# Out:
# Coding For All

# %%
# Which one of the following variables return True when we use the method isidentifier():
#30DaysOfPython
# thirty_days_of_python 
var1 = "30DaysOfPython"
var2 = "thirty_days_of_python"
is_var1_identifier=var1.isidentifier()
is_var2_identifier=var2.isidentifier()
print(f"Is var1 a valid identifier?: {is_var1_identifier}")
print(f"Is var2 a valid identifier?: {is_var2_identifier}")
# Out:
# Is var1 a valid identifier?: False
# Is var2 a valid identifier?: True

# %%
# The following list contains the names of some of python libraries: ['Django', 'Flask', 
# 'Bottle', 'Pyramid', 'Falcon']. Join the list with a hash with space string.
libraries = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
joined_string= " # ".join(libraries)
print(joined_string)
# Out:
# Django # Flask # Bottle # Pyramid # Falcon

# %%
# Use the new line escape sequence to separate the following sentences.
# I am enjoying this challenge.
# I just wonder what is next.
sentence = "I am enjoying this challenge.\nI just wonder what is next."
print(sentence)
# Out:
# I am enjoying this challenge.
# I just wonder what is next.

# %%
# Use a tab escape sequence to write the following lines
# Name Age Country City Asabeneh 250 Finland Helsinki
text = "Name\t\tAge\t\tCountry\t\tCity\t\t\nAsabeneh\t250\t\tFinland\t\tHelsink"
print(text)
# Out:
# Name		Age		Country		City
# Asabeneh	250		Finland		Helsink

# %%
# Using the string formatting method to display the following:
# radius = 10
# area = 3.14 * radius ** 2
# The area of a circle with radius 10 is 314 meters square.
radius = 10
area = 3.14 * radius ** 2
result = "The area of a circle with radius {} is {} meters square.".format(radius, area)
print(result)
# Out:
# The area of a circle with radius 10 is 314.0 meters square.

# %%
# Make the following using string formatting methods:
#8 + 6 = 14, 8 - 6 = 2, 8 * 6 = 48, 8 / 6 = 1.33, 8 % 6 = 2, 8 // 6 = 1, 8 ** 6 = 262144
a = 8
b =6
addition = a + b
addition_result = "{} + {} = {}".format(a,b, addition)
print(addition_result)
# Out:
# 8 + 6 = 14

# %%
subtraction = a - b
subtraction_result = "{} - {} = {}".format(a,b, subtraction)
print(subtraction_result)
# Out:
# 8 - 6 = 2

# %%
multiplication = a * b
multiplication_result = "{} * {} = {}".format(a,b, multiplication)
print(multiplication_result)
# Out:
# 8 * 6 = 48

# %%
division = a / b
division_result = "{} / {} = {}".format(a,b, division)
print(division_result)
# Out:
# 8 / 6 = 1.3333333333333333

# %%
modulus = a % b
modulus_result = "{} % {} = {}".format(a,b, modulus)
print(modulus_result)
# Out:
# 8 % 6 = 2

# %%
floor_division = a // b
floor_division_result = "{} // {} = {}".format(a,b, floor_division)
print(floor_division_result)
# Out:
# 8 // 6 = 1

# %%
exponential = a ** b
exponential_result = "{} ** {} = {}".format(a,b, exponential)
print(exponential_result)
# Out:
# 8 ** 6 = 262144

# %%
pwd
# Out:
# 'C:\\Users\\nehem\\ML Class\\Introduction'
